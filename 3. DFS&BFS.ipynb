# %% [markdown]
# # 탐색 알고리즘
#
# - 탐색이란 많은 양의 데이터 중에서 원하는 데이터를 찾는 과정을 말합니다.
# - 대표적인 그래프 탐색 알고리즘은 DFS와 BFS가 있다.
# - DFS/BFS는 코딩 테스트에서 매우 자주 등장하는 유형이므로 반드시 숙지!!

# %% [markdown]
# ## 스택

# %%
stack = []

stack.append(5)
stack.append(2)
stack.append(3)
stack.append(7)
stack.pop()
stack.append(1)
stack.append(4)
stack.pop()

print(stack[::-1]) # 뒤집기
print(stack)
# Out:
# [1, 3, 2, 5]
# [5, 2, 3, 1]

# %% [markdown]
# ## 큐

# %%
from collections import deque # 리스트로도 큐를 구현할 수 있지만, 시간 복잡도가 높아지므로 deque 라이브러리 사용

queue = deque()

queue.append(5)
queue.append(2)
queue.append(3)
queue.append(7)
queue.popleft()
queue.append(1)
queue.append(4)
queue.popleft()

print(queue) # 먼저 들어온 순서대로 출력
queue.reverse() # 역순으로 바꾸기
print(queue) # 나중에 들어온 원소부터 출력
# Out:
# deque([3, 7, 1, 4])
# deque([4, 1, 7, 3])

# %% [markdown]
# ## 재귀 함수
#
# - 재귀함수란 자기 자신을 다시 호출하는 함수를 의미(recursive function)
# - 파이썬은 어느 정도 출력하다가 최대 재귀 깊이 초과 메시지가 출력

# %%
# 재귀함수 예시
def recursive_func():
    print("재귀함수 호출")
    recursive_func()

recursive_func()
# Out:
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# ...

# %%
def recursive_func(i):
    if i==4:
        return
    print(f"{i}번째 재귀함수에서 {i+1}번째 재귀함수를 호출")
    recursive_func(i+1)
    print(f"{i}번째 재귀함수 종료~")
    print('-------------------')

# %%
recursive_func(1)
# Out:
# 1번째 재귀함수에서 2번째 재귀함수를 호출
# 2번째 재귀함수에서 3번째 재귀함수를 호출
# 3번째 재귀함수에서 4번째 재귀함수를 호출
# 3번째 재귀함수 종료~
# -------------------
# 2번째 재귀함수 종료~
# -------------------
# 1번째 재귀함수 종료~
# -------------------

# %% [markdown]
# ## 팩토리얼
#
# - n! = 1x2x3x ... x(n-1)x n
# - 1부터 n까지 차례대로 곱하기
# - 수학적으로 0!과 1!의 값은 1이다

# %% [markdown]
# #### 반복문으로 구현한 n!

# %%
def factorial_iterative(n):
    result =1
    for i in range(1,n+1):
        result*=i
    return result
factorial_iterative(5)
# Out:
# 120

# %%
def factorial_recursive(n):
    if n <= 1: # n이 1이하인 경우 1을 반환
        return 1
    return n * factorial_recursive(n-1)
factorial_recursive(5)
# Out:
# 120

# %% [markdown]
# #### 최대공약수 계산(유클리드 호제법)
#
# - 유클리드 호제법
#     - 두 자연수 A,B에 대하여 A가 B보다 클 때, A%B(나머지) 값을 R이라고 합시다.
#     - 이 때 A와 B의 최대고약수는 B와 R의 최대공약수와 같다

# %%
def gcd(a,b):
    if a%b==0: # a가 b의 배수라면
        return b
    else:
         return gcd(b,a%b)
gcd(192,162)
# Out:
# 6
